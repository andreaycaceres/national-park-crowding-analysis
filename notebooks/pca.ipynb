# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
park_agg = pd.read_csv("../data/clean/park_agg.csv")
park_agg.head()
# Out:
#      Park Name  Recreation Visits  Non Recreation Visits  Recreation Hours  \
# 0    Acadia NP      297181.590909            3925.000000      1.931537e+06
# 1    Arches NP      127372.462121             125.484848      5.245314e+05
# 2  Badlands NP       86726.174242            5311.272727      3.805244e+05
# 3  Big Bend NP       39713.340909             207.181818      8.469260e+05
# 4  Biscayne NP       45659.689394               0.000000      1.457889e+05
#
#    Non Recreation Hours  Concessioner Lodging  Concessioner Camping  \
# 0           3925.000000              0.000000            104.825758
# 1            125.484848              0.000000              0.000000
# 2           5311.272727            802.356061           2125.492424
# 3            207.181818           2717.181818            616.053030
# 4              0.000000              0.000000              0.000000
#
#    Tent Campers   RV Campers  Backcountry  Non Recreation Overnight Stays  \
# 0  10320.848485  3754.424242   106.265152                             0.0
# 1   1339.030303  1406.000000    32.174242                             0.0
# 2    325.030303    72.454545   192.409091                             0.0
# 3   4288.750000  2258.462121  3197.219697                             0.0
# 4    128.962121     0.000000     0.000000                             0.0
#
#    Miscellaneous Overnight Stays  Number of Activities  Entrance Fees
# 0                     698.704545                  46.0            6.0
# 1                     457.840909                  18.0           30.0
# 2                       6.598485                  21.0           30.0
# 3                    2354.234848                  24.0           30.0
# 4                     238.113636                  24.0            0.0

# %%
pca_feat = ['Non Recreation Visits','Non Recreation Hours','Concessioner Lodging','Concessioner Camping','Tent Campers','RV Campers','Backcountry',
'Miscellaneous Overnight Stays','Number of Activities','Entrance Fees']
x = park_agg[pca_feat]
x_scaled = StandardScaler().fit_transform(x)
pca = PCA(n_components=2)
prin_comp = pca.fit_transform(x_scaled)
pca_df = pd.DataFrame(prin_comp,columns=['PC1', 'PC2'])
pca_df['Park Name'] = park_agg['Park Name']
print(pca.explained_variance_ratio_)
pca_df.head()

plt.figure(figsize=(10,6))
plt.scatter(pca_df['PC1'], pca_df['PC2'])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of National Park Features')

for i, park in enumerate(park_agg['Park Name']):
    plt.annotate(
        park,
        (pca_df['PC1'][i], pca_df['PC2'][i]),
        fontsize=8
    )
# Out:
# [0.36904341 0.19660692]
# array([[ 0.23401992,  0.23401992,  0.40584213,  0.16611869,  0.45354221,
#          0.45675257,  0.39799172,  0.20618973,  0.16507278,  0.23597037],
#        [ 0.60558771,  0.60558771, -0.3023374 , -0.17998887, -0.04032141,
#         -0.00568547, -0.11404972,  0.13872522, -0.13268159, -0.30200761]])

# %%
print(pca.explained_variance_ratio_)
pca.components_

loadings = pd.DataFrame(
    pca.components_.T,
    columns=['PC1','PC2'],
    index=pca_feat
)

print(loadings)
# Out:
# [0.36904341 0.19660692]
#                                     PC1       PC2
# Non Recreation Visits          0.234020  0.605588
# Non Recreation Hours           0.234020  0.605588
# Concessioner Lodging           0.405842 -0.302337
# Concessioner Camping           0.166119 -0.179989
# Tent Campers                   0.453542 -0.040321
# RV Campers                     0.456753 -0.005685
# Backcountry                    0.397992 -0.114050
# Miscellaneous Overnight Stays  0.206190  0.138725
# Number of Activities           0.165073 -0.132682
# Entrance Fees                  0.235970 -0.302008

# %%
plt.figure(figsize=(8,5))
plt.plot(range(1, len(pca.explained_variance_ratio_)+1),pca.explained_variance_ratio_,marker='o')
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.show()
